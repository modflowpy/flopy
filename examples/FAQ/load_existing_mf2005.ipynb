# %%
# %matplotlib inline
import os
import sys
import flopy

print(sys.version)
print('flopy version: {}'.format(flopy.__version__))
# Out:
# 3.6.4 | packaged by conda-forge | (default, Dec 23 2017, 16:54:01)
# [GCC 4.2.1 Compatible Apple LLVM 6.1.0 (clang-602.0.53)]
# flopy version: 3.2.9

# %% [markdown]
# **Load an existing MODFLOW-2005 model**
#
# * `verbose=True` writes diagnostic information during the load and can be used to troubleshoot issues encountered during in the `.load()` method.
# * `check=False` disables basic FloPy error checking.

# %%
model_ws = os.path.join('..', 'data', 'mf2005_test')
ml = flopy.modflow.Modflow.load('bcf2ss.nam', model_ws=model_ws, verbose=True,
                               version='mf2005', check=False)
# Out:
# Creating new model with name: bcf2ss
# --------------------------------------------------
#
# Parsing the namefile --> ../data/mf2005_test/bcf2ss.nam
# could not set filehandle to bcf2ss.lst
#
# --------------------------------------------------
# External unit dictionary:
# {7: filename:../data/mf2005_test/bcf2ss.lst, filetype:LIST, 8: filename:../data/mf2005_test/bcf2ss.ba6, filetype:BAS6, 11: filename:../data/mf2005_test/bcf2ss.bc6, filetype:BCF6, 12: filename:../data/mf2005_test/bcf2ss.wel, filetype:WEL, 14: filename:../data/mf2005_test/bcf2ss.riv, filetype:RIV, 18: filename:../data/mf2005_test/bcf2ss.rch, filetype:RCH, 19: filename:../data/mf2005_test/bcf2ss.pcg, filetype:PCG, 20: filename:../data/mf2005_test/bcf2ss.oc, filetype:OC, 10: filename:../data/mf2005_test/bcf2ss.dis, filetype:DIS}
# --------------------------------------------------
#
# ModflowBas6 free format:True
#
# loading dis package file...
#    Loading dis package with:
# ...
